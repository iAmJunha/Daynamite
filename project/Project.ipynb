# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
os.chdir(r"C:\Users\박유경\Desktop\project")
#os.chdir(r"C:\Users\student\Desktop\20190118_Python 분석 기초\data")

# %%
# df = pd.read_csv('data_population.csv', header='infer',encoding='ISO-8859-1')
df = pd.read_csv('credit_card_data.csv', header='infer', na_values=[' '])
df
# Out:
#      pop_cd  year  month  avg_score  avg_rat city  sex ages  population  \
# 0      L011  2016      1        812        2   서울  NaN  10대       55000
# 1      L011  2016      2        773        4   서울  NaN  10대      380000
# 2      L011  2016      3        771        4   서울  NaN  10대      387000
# 3      L011  2016      4        770        4   서울  NaN  10대      412000
# 4      L011  2016      5        771        4   서울  NaN  10대      414000
# ...     ...   ...    ...        ...      ...  ...  ...  ...         ...
# 3883    Y95  2017      8        819        3  NaN   여자  90대      232000
# 3884    Y95  2017      9        819        3  NaN   여자  90대      235000
# 3885    Y95  2017     10        819        3  NaN   여자  90대      239000
# 3886    Y95  2017     11        819        3  NaN   여자  90대      243000
# 3887    Y95  2017     12        820        3  NaN   여자  90대      265000
#
#       num_opencard  ...  monthly_installments_loan  monthly_insurance_loan  \
# ...

# %%
df.shape
# Out:
# (3888, 26)

# %%
df_s=df[(df.sex =='남자') | (df.sex=='여자')]
df_s
# Out:
#      pop_cd  year  month  avg_score  avg_rat city sex ages  population  \
# 384     Y10  2016      1        811        2  NaN  남자  10대      960000
# 385     Y10  2016      2        767        4  NaN  남자  10대     1144000
# 386     Y10  2016      3        765        4  NaN  남자  10대     1168000
# 387     Y10  2016      4        764        4  NaN  남자  10대     1211000
# 388     Y10  2016      5        765        4  NaN  남자  10대     1216000
# ...     ...   ...    ...        ...      ...  ...  ..  ...         ...
# 3883    Y95  2017      8        819        3  NaN  여자  90대      232000
# 3884    Y95  2017      9        819        3  NaN  여자  90대      235000
# 3885    Y95  2017     10        819        3  NaN  여자  90대      239000
# 3886    Y95  2017     11        819        3  NaN  여자  90대      243000
# 3887    Y95  2017     12        820        3  NaN  여자  90대      265000
#
#       num_opencard  ...  monthly_installments_loan  monthly_insurance_loan  \
# ...

# %%
df_r=df[-((df.sex=='남자') | (df.sex=='여자'))]
df_r
# Out:
#      pop_cd  year  month  avg_score  avg_rat city  sex ages  population  \
# 0      L011  2016      1        812        2   서울  NaN  10대       55000
# 1      L011  2016      2        773        4   서울  NaN  10대      380000
# 2      L011  2016      3        771        4   서울  NaN  10대      387000
# 3      L011  2016      4        770        4   서울  NaN  10대      412000
# 4      L011  2016      5        771        4   서울  NaN  10대      414000
# ...     ...   ...    ...        ...      ...  ...  ...  ...         ...
# 3835   L169  2017      8        810        3   제주  NaN  90대        2000
# 3836   L169  2017      9        809        3   제주  NaN  90대        2000
# 3837   L169  2017     10        809        3   제주  NaN  90대        2000
# 3838   L169  2017     11        810        3   제주  NaN  90대        2000
# 3839   L169  2017     12        811        3   제주  NaN  90대        2000
#
#       num_opencard  ...  monthly_installments_loan  monthly_insurance_loan  \
# ...

# %%
print(df_r[df_r['avg_rat'].isin(['8'])])
# Out:
# Empty DataFrame
# Columns: [pop_cd, year, month, avg_score, avg_rat, city, sex, ages, population, num_opencard, num_usecard, monthly_card_spend, monthly_lc, monthly_loan, monthly_bk_loan, monthly_cd_loan, monthly_installments_loan, monthly_insurance_loan, monthly_sbk_loan, loan_commitment, inst_rep_loanb, ls_rep_loanb, credit_loan, mortgage_loan, credit_card_payment, credit_card_installments_payment]
# Index: []
#
# [0 rows x 26 columns]

# %%
opencard_age=df_r['num_opencard'].groupby(df_r['ages']) #연령별 개설 카드수

# %%
opencard_age.mean()
# Out:
# ages
# 10대    1.706484
# 20대    3.676615
# 30대    4.249193
# 40대    3.840781
# 50대    3.144297
# 60대    2.253021
# 70대    1.303542
# 80대    0.672344
# 90대    0.273750
# Name: num_opencard, dtype: float64

# %%
usecard_age=df_r['num_usecard'].groupby(df_r['ages']) #연령별 이용 카드 수

# %%
usecard_age.mean()
# Out:
# ages
# 10대    1.051615
# 20대    1.789740
# 30대    2.224141
# 40대    2.190651
# 50대    1.839219
# 60대    1.328620
# 70대    0.727630
# 80대    0.314479
# 90대    0.109922
# Name: num_usecard, dtype: float64

# %%
# 연령별 개설 카드 수 이용 카드 수 비교
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.font_manager as fm
import pyecharts

font_location = 'c:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = font_location).get_name()
matplotlib.rc('font', family = font_name)

# x=df_r['ages']
# y1=df_r['num_opencard']
# y2=df_r['num_usecard']

# # fig, ax1 = plt.subplots()
# # ax2 = ax1.twinx()

# # line1=ax1.plot(np.arange(len(x)), y1, color='b',linestyle='--' , marker='o' , label='opencard')
# # line2=ax2.plot(np.arange(len(x)), y2, color='g',linestyle='--' , marker='^', label='usecard')


# # ax1.set_xticklabels(x)
# # ax1.set_xlabel('ages')
# # ax1.set_ylabel('opencard')
# # ax2.set_ylabel('usecard')

# # ax1.set_ylim(0,6)
# # ax2.set_ylim(0,6)

# # lines = line1 + line2
# # labels = [l.get_label() for l in lines]
# # plt.legend(lines,labels,loc=2)

# # plt.grid(False)

# # fig.tight_layout()
# # fig.savefig('Carduse.png' , dpi=1000)

# bar = pyecharts.Bar("Bar chart", "precipitation and evaporation one year")
# bar.use_theme("dark")
# bar.add("opencard", x, y1, mark_line=["average"], mark_point=["max", "min"])
# bar.add("usecard", x, y2, mark_line=["average"], mark_point=["max", "min"])
# bar.height = 500
# bar.width = 800
# bar
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-08ff5e1897bb> in <module>
#      37 # fig.savefig('Carduse.png' , dpi=1000)
#      38
# ---> 39 bar = pyecharts.Bar("Bar chart", "precipitation and evaporation one year")
#      40 bar.use_theme("dark")
#      41 bar.add("opencard", x, y1, mark_line=["average"], mark_point=["max", "min"])
#
# AttributeError: module 'pyecharts' has no attribute 'Bar'

# %%
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.font_manager as fm
import pyecharts

font_location = 'c:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = font_location).get_name()
matplotlib.rc('font', family = font_name)
