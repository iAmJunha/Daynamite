# %%
#import tkinter
from tkinter import *
from tkinter import messagebox
from tkinter import ttk


window=tkinter.Tk()

window.title("JEJU MAP")
window.geometry("300x300+200+100")
window.resizable(False, False)

count=0

label1 = Label(window, text="계산방법:")
btn1 = Button(window, text='합계') # 버튼을 올릴 장소, 버튼에 들어갈 내용
btn2 = Button(window, text='평균')

# label1.grid(row=0,column=0)
# btn1_1.grid(row=0, column=1)
# btn1_2.grid(row=0, column=2) 

label1.pack()# auto 위치 지정
btn1.pack() 
btn2.pack()


label2 = Label(window, text="수치:")
str = StringVar()
label2.pack()# auto 위치 지정
Combobox1 = ttk.Combobox(textvariable=str, width=20)
Combobox1['value'] = ('1','2','3','4','5')
Combobox1.current(0)
Combobox1.pack()




label3 = Label(window, text="성별:")
btn3_1 = Button(window, text='전체') # 버튼을 올릴 장소, 버튼에 들어갈 내용
btn3_2 = Button(window, text='남성')
btn3_3 = Button(window, text='여성')

label3.pack()# auto 위치 지정
btn3_1.pack() 
btn3_2.pack()
btn3_3.pack()


label4 = Label(window, text="직업:")
btn4_1 = Button(window, text='전체') # 버튼을 올릴 장소, 버튼에 들어갈 내용
btn4_2 = Button(window, text='대기업')
btn4_3 = Button(window, text='중소기업')
btn4_4 = Button(window, text='공기업')
btn4_5 = Button(window, text='전문직')
btn4_6 = Button(window, text='자영업')
btn4_7 = Button(window, text='무직')
btn4_8 = Button(window, text='기타')


label4.pack()# auto 위치 지정
btn4_1.pack() 
btn4_2.pack()
btn4_3.pack()
btn4_4.pack() 
btn4_5.pack()
btn4_6.pack()
btn4_7.pack() 
btn4_8.pack()



label5 = Label(window, text="신용등급")
label5.pack()


label6 = Label(window, text="연령대")
label6.pack()



window.mainloop()
